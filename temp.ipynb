# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# path = r'C:\Users\jing\Desktop\不良品废品日报表.xlsx(2).xlsx'

# %%
# df1 = pd.read_excel(path, sheet_name=0, header=1, skipfooter=11)
# # df1 = df1[(df1['日期']>=2.26) & (df1['日期']<=5.20)]
# df1.head()

# %%
# df2 = pd.read_excel(path, sheet_name=1, header=1, skipfooter=13)
# df2.head()

# %%
# df1[['不良率','废品率']].sum().values

# %%
# df2[['不良率','废品率']].sum()

# %%
# df1.groupby(['零件号']).sum()[['不良率','废品率']].sort_values('废品率',ascending=False).reset_index().values

# %%
# df1.groupby(['工序简称']).sum()[['不良率','废品率']].sort_values('废品率', ascending=False).head().reset_index().values

# %%
# df1.groupby(['零件号','工序简称']).sum()[['不良率','废品率']].loc['STL'].sort_values('废品率',ascending=False).head().reset_index().values

# %%
# df1['原因'].value_counts().head(10)

# %%
# df1['工序简称'].value_counts().head(10)

# %%
# df1['零件号'].value_counts().head(10)

# %%
path1 = r"C:\Users\jing\Desktop\app\Pump Demo\Pump Training Data.csv"
path2 = r"C:\Users\jing\Desktop\app\Pump Demo\Pump Test Data.csv"

# %%
df = pd.read_csv(path1).iloc[4:,1:]
df = df.astype('float')
df.head()

# %%
dftest = pd.read_csv(path2).iloc[4:,1:]
dftest = dftest.astype('float')
dftest.head()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import KDTree

scaler = StandardScaler()
x = scaler.fit_transform(df)
# x = df
y = scaler.fit_transform(dftest)
# y = np.array(dftest)
d = pairwise_distances(x,y)

# %%
d

# %%
d.shape

# %%
np.sort(d[:,0])

# %%
s = []
for i in range(d.shape[1]):
    s.append(np.sqrt(((1/(d[:,i]+1))**2).sum()))

# %%
plt.plot(s)

# %%
r =[]
for i in range(d.shape[1]):
    r.append(d[:,i]/np.sqrt((d[:,i]**2).sum()))

# %%
rr = []
for i in range(len(r)):
    rr.append(r[i].min())

# %%
h = [1-i for i in rr]
plt.figure(figsize=(16,8))
plt.plot(h)

# %%
tree = KDTree(x)
tree.query(y[0].reshape(1,-1),k=3)

# %%
r = []
for i in range(len(y)):
    r.append(cosine_similarity(x,y[i:i+1]).max())

# %%
plt.plot(r)

# %%
import sqlalchemy
import pymssql


# 连接Microsoft SQL Server数据库
conn = sqlalchemy.create_engine('mssql+pymssql://sa:123456@192.168.1.95/LSDB?charset=cp936')  # charset=cp936解决了数据库编码为GBK时，数据读取中文乱码的问题

# %%
sql = "select * from table1 where name like ('%Brand\Brand22%')"
# sql = "select * from table1 where name like ('%pres\mlp_R%')"
# sql = "select * from table1 where name like ('%sevo\%')"
# sql = "select * from table1"
df = pd.read_sql(sql, conn)
df
# Out:
#                                                    Name     pv  \
# 0     Brand\Brand22\line3                           ...   66.0
# 1     Brand\Brand22\line3                           ...   66.0
# 2     Brand\Brand22\line3                           ...   66.0
# 3     Brand\Brand22\line3                           ...   66.0
# 4     Brand\Brand22\line3                           ...   66.0
# 5     Brand\Brand22\line3                           ...   66.0
# 6     Brand\Brand22\line3                           ...   66.0
# 7     Brand\Brand22\line3                           ...   66.0
# 8     Brand\Brand22\line5                           ...  110.0
# 9     Brand\Brand22\line5                           ...  110.0
# 10    Brand\Brand22\line5                           ...  110.0
# 11    Brand\Brand22\line5                           ...  110.0
# 12    Brand\Brand22\line5                           ...  110.0
# 13    Brand\Brand22\line5                           ...  110.0
# ...
